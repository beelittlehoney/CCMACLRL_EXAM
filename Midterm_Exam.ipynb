# %% [markdown]
# <a href="https://colab.research.google.com/github/beelittlehoney/CCMACLRL_EXAM/blob/main/Midterm_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Glodo', 'Rico', 'Guelos')
# Out:
# Glodo Rico Guelos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
dataset_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/a46a4e2a001dedaefc9b431d480b508ce86c2d96/datasets/train.csv?raw=true'
df = pd.read_csv(dataset_url)
df.head()
# Out:
#    id          brand              model  model_year  milage      fuel_type  \
# 0   0           MINI      Cooper S Base        2007  213000       Gasoline
# 1   1        Lincoln              LS V8        2002  143250       Gasoline
# 2   2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3   3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4   4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine  \
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col  \
# 0                             A/T  Yellow    Gray
# 1                             A/T  Silver   Beige
# 2                             A/T    Blue    Gray
# 3  Transmission w/Dual Shift Mode   Black   Black
# 4                     7-Speed A/T   Black   Beige
#
#                                  accident clean_title  price
# 0                           None reported         Yes   4200
# 1  At least 1 accident or damage reported         Yes   4999
# 2                           None reported         Yes  13900
# 3                           None reported         Yes  45000
# 4                           None reported         Yes  97500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            188533 non-null  int64
#  1   brand         188533 non-null  object
#  2   model         188533 non-null  object
#  3   model_year    188533 non-null  int64
#  4   milage        188533 non-null  int64
#  5   fuel_type     183450 non-null  object
#  6   engine        188533 non-null  object
#  7   transmission  188533 non-null  object
#  8   ext_col       188533 non-null  object
#  9   int_col       188533 non-null  object
#  10  accident      186081 non-null  object
#  11  clean_title   167114 non-null  object
#  12  price         188533 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 18.7+ MB

# %%
df.isnull().sum()
# Out:
# id                  0
# brand               0
# model               0
# model_year          0
# milage              0
# fuel_type        5083
# engine              0
# transmission        0
# ext_col             0
# int_col             0
# accident         2452
# clean_title     21419
# price               0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# id              0
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# ext_col         0
# int_col         0
# accident        0
# clean_title     0
# price           0
# dtype: int64

# %%
df.describe()
# Out:
#                   id     model_year         milage         price
# count  162610.000000  162610.000000  162610.000000  1.626100e+05
# mean    94197.039137    2015.158822   71105.487086  4.081699e+04
# std     54467.770815       5.699531   50157.874111  7.653857e+04
# min         0.000000    1974.000000     100.000000  2.000000e+03
# 25%     47026.250000    2012.000000   29000.000000  1.570000e+04
# 50%     94139.000000    2016.000000   64300.000000  2.850000e+04
# 75%    141421.750000    2019.000000  101000.000000  4.699900e+04
# max    188532.000000    2024.000000  405000.000000  2.954083e+06

# %%
df.sample(20)
# Out:
#             id          brand                        model  model_year  \
# 168986  168986  Mercedes-Benz          GLS 450 Base 4MATIC        2017
# 109072  109072            BMW                 328 i xDrive        2011
# 188222  188222         Jaguar                        XJ8 L        1997
# 105727  105727       Cadillac           Escalade ESV Sport        2018
# 47897    47897          Buick              Enclave Premium        2019
# 138439  138439           Audi                      A8 L 55        2022
# 71242    71242  Mercedes-Benz  C-Class C 300 4MATIC Luxury        2012
# 57755    57755         Toyota               Highlander XLE        2021
# 133512  133512           Audi               Q7 55 Prestige        2019
# 66553    66553          Lexus             LX 570 Three-Row        2018
# 21665    21665            BMW                 335 i xDrive        2012
# 67240    67240         Hummer                      H2 Base        2005
# 21924    21924    Rolls-Royce                      Phantom        2015
# 141718  141718           Ford        Expedition Timberline        2021
# 28075    28075       INFINITI                    QX56 Base        2014
# 80411    80411        Lincoln                  MKX Reserve        2019
# 99155    99155          Honda                   S2000 Base        2000
# 170292  170292      Chevrolet                  Suburban LT        2017
# 144528  144528            BMW            X5 PHEV xDrive45e        2022
# 75065    75065          Dodge                 Dakota Sport        1997
#
#         milage       fuel_type  \
# 168986   49000        Gasoline
# 109072  150000        Gasoline
# 188222   50000        Gasoline
# 105727   49620        Gasoline
# 47897    25462        Gasoline
# 138439   27100          Hybrid
# 71242   111300        Gasoline
# 57755    48500        Gasoline
# 133512   62662          Hybrid
# 66553    67289        Gasoline
# 21665    87066        Gasoline
# 67240   171000        Gasoline
# 21924    79422        Gasoline
# 141718   12209        Gasoline
# 28075   107555        Gasoline
# 80411    56675        Gasoline
# 99155    96000        Gasoline
# 170292   99000        Gasoline
# 144528   32000  Plug-In Hybrid
# 75065   149437        Gasoline
#
#                                                    engine  \
# 168986      362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 109072  230.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 188222       290.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 105727       420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 47897                                3.6L V6 24V GDI DOHC
# 138439  335.0HP 3.0L V6 Cylinder Engine Gasoline/Mild ...
# 71242       248.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 57755       295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 133512  335.0HP 3.0L V6 Cylinder Engine Gasoline/Mild ...
# 66553        381.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 21665   300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 67240        325.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 21924       624.0HP 6.6L 12 Cylinder Engine Gasoline Fuel
# 141718                    3.5L V6 24V PDI DOHC Twin Turbo
# 28075        400.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 80411       335.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 99155        240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 170292       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 144528  389.0HP 3.0L Straight 6 Cylinder Engine Plug-I...
# 75065        230.0HP 5.2L 8 Cylinder Engine Gasoline Fuel
#
#                           transmission               ext_col  \
# 168986                     9-Speed A/T                  Blue
# 109072                             A/T                 Black
# 188222                             A/T                  Gold
# 105727                    10-Speed A/T                  Gray
# 47897                9-Speed Automatic          Summit White
# 138439  Transmission w/Dual Shift Mode                 Black
# 71242                              A/T                 White
# 57755                      8-Speed A/T                  Blue
# 133512                             A/T                  Gray
# 66553                              A/T                 White
# 21665                      8-Speed A/T                 White
# 67240                              A/T                 Brown
# 21924                      8-Speed A/T                 Black
# 141718              10-Speed Automatic  Agate Black Metallic
# 28075                      7-Speed A/T                 White
# 80411   Transmission w/Dual Shift Mode                  Gray
# 99155                      6-Speed A/T                   Red
# 170292                     6-Speed A/T                 Black
# 144528  Transmission w/Dual Shift Mode                Silver
# 75065                              A/T                   Red
#
#                    int_col                                accident  \
# 168986               Beige                           None reported
# 109072               Black  At least 1 accident or damage reported
# 188222               Beige                           None reported
# 105727               Black                           None reported
# 47897   Medium Light Camel                           None reported
# 138439               Black                           None reported
# 71242                Beige  At least 1 accident or damage reported
# 57755                Black                           None reported
# 133512               Black  At least 1 accident or damage reported
# 66553                Brown                           None reported
# 21665                Beige                           None reported
# 67240                Beige                           None reported
# 21924                Black                           None reported
# 141718               Black                           None reported
# 28075                Beige                           None reported
# 80411                Brown                           None reported
# 99155                  Red  At least 1 accident or damage reported
# 170292               Black                           None reported
# 144528               Black                           None reported
# 75065                 Gray                           None reported
#
#        clean_title   price
# 168986         Yes   32900
# 109072         Yes   10000
# 188222         Yes    5500
# 105727         Yes   55000
# 47897          Yes   39995
# 138439         Yes   47500
# 71242          Yes   12000
# 57755          Yes   43000
# 133512         Yes   32000
# 66553          Yes   23000
# 21665          Yes   18000
# 67240          Yes    6099
# 21924          Yes  215000
# 141718         Yes   68362
# 28075          Yes   26000
# 80411          Yes   36000
# 99155          Yes    4199
# 170292         Yes   29000
# 144528         Yes   62000
# 75065          Yes   12500

# %%
from datetime import datetime

current_year = datetime.now().year
df['model_year'] = current_year - df['model_year'].astype(int)
df.head()
# Out:
#    id          brand              model  model_year  milage      fuel_type  \
# 0   0           MINI      Cooper S Base          17  213000       Gasoline
# 1   1        Lincoln              LS V8          22  143250       Gasoline
# 2   2      Chevrolet  Silverado 2500 LT          22  136731  E85 Flex Fuel
# 3   3        Genesis   G90 5.0 Ultimate           7   19500       Gasoline
# 4   4  Mercedes-Benz        Metris Base           3    7388       Gasoline
#
#                                               engine  \
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col  \
# 0                             A/T  Yellow    Gray
# 1                             A/T  Silver   Beige
# 2                             A/T    Blue    Gray
# 3  Transmission w/Dual Shift Mode   Black   Black
# 4                     7-Speed A/T   Black   Beige
#
#                                  accident clean_title  price
# 0                           None reported         Yes   4200
# 1  At least 1 accident or damage reported         Yes   4999
# 2                           None reported         Yes  13900
# 3                           None reported         Yes  45000
# 4                           None reported         Yes  97500

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
label_encoder = LabelEncoder()
df['brand'] = label_encoder.fit_transform(df['brand'])
df['model'] = label_encoder.fit_transform(df['model'])
df['fuel_type'] = label_encoder.fit_transform(df['fuel_type'])
df['engine'] = label_encoder.fit_transform(df['engine'])
df['transmission'] = label_encoder.fit_transform(df['transmission'])
df['ext_col'] = label_encoder.fit_transform(df['ext_col'])
df['int_col'] = label_encoder.fit_transform(df['int_col'])
df['accident'] = label_encoder.fit_transform(df['accident'])
df['clean_title'] = label_encoder.fit_transform(df['clean_title'])

# %%
df
# Out:
#             id  brand  model  model_year  milage  fuel_type  engine  \
# 0            0     31    493          17  213000          2     110
# 1            1     28    925          22  143250          2     358
# 2            2      9   1567          22  136731          1     627
# 3            3     16    755           7   19500          2     846
# 4            4     36   1072           3    7388          2     252
# ...        ...    ...    ...         ...     ...        ...     ...
# 188527  188527      9    402          25  110000          2     604
# 188528  188528      8    601           7   49000          2     849
# 188529  188529     36    204           6   28600          2     757
# 188530  188530     36    221           3   13650          2     904
# 188532  188532     43   1023           8   59500          2     356
#
#         transmission  ext_col  int_col  accident  clean_title  price
# 0                 38      306       71         1            0   4200
# 1                 38      257       10         0            0   4999
# 2                 38       37       71         1            0  13900
# 3                 49       28       14         1            0  45000
# 4                 23       28       10         1            0  97500
# ...              ...      ...      ...       ...          ...    ...
# 188527            38      298       71         1            0  14500
# 188528            49      298       10         1            0  27500
# 188529            31      298       14         0            0  30000
# 188530            23      298       14         1            0  86900
# 188532            49      298       14         1            0  28995
#
# [162610 rows x 13 columns]

# %%
y_scaled = df['price']
y_scaled
# Out:
# 0          4200
# 1          4999
# 2         13900
# 3         45000
# 4         97500
#           ...
# 188527    14500
# 188528    27500
# 188529    30000
# 188530    86900
# 188532    28995
# Name: price, Length: 162610, dtype: int64

# %%
x = df.drop(['price'],axis=1)
x
# Out:
#             id  brand  model  model_year  milage  fuel_type  engine  \
# 0            0     31    493          17  213000          2     110
# 1            1     28    925          22  143250          2     358
# 2            2      9   1567          22  136731          1     627
# 3            3     16    755           7   19500          2     846
# 4            4     36   1072           3    7388          2     252
# ...        ...    ...    ...         ...     ...        ...     ...
# 188527  188527      9    402          25  110000          2     604
# 188528  188528      8    601           7   49000          2     849
# 188529  188529     36    204           6   28600          2     757
# 188530  188530     36    221           3   13650          2     904
# 188532  188532     43   1023           8   59500          2     356
#
#         transmission  ext_col  int_col  accident  clean_title
# 0                 38      306       71         1            0
# 1                 38      257       10         0            0
# 2                 38       37       71         1            0
# 3                 49       28       14         1            0
# 4                 23       28       10         1            0
# ...              ...      ...      ...       ...          ...
# 188527            38      298       71         1            0
# 188528            49      298       10         1            0
# 188529            31      298       14         0            0
# 188530            23      298       14         1            0
# 188532            49      298       14         1            0
#
# [162610 rows x 12 columns]

# %% [markdown]
# 1. Use the Dataset file to train your model. Split this into train and test to calculate the RMSE

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y_scaled, test_size=0.7, random_state=51)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 72567.53633609145

# %%
test_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/a46a4e2a001dedaefc9b431d480b508ce86c2d96/datasets/test.csv?raw=true'
dt = pd.read_csv(test_url)

# %%
sample_submission_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/a46a4e2a001dedaefc9b431d480b508ce86c2d96/datasets/sample_submission.csv?raw=true'
sf = pd.read_csv(sample_submission_url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162610 entries, 0 to 188532
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            162610 non-null  int64
#  1   brand         162610 non-null  int64
#  2   model         162610 non-null  int64
#  3   model_year    162610 non-null  int64
#  4   milage        162610 non-null  int64
#  5   fuel_type     162610 non-null  int64
#  6   engine        162610 non-null  int64
#  7   transmission  162610 non-null  int64
#  8   ext_col       162610 non-null  int64
#  9   int_col       162610 non-null  int64
#  10  accident      162610 non-null  int64
#  11  clean_title   162610 non-null  int64
#  12  price         162610 non-null  int64
# dtypes: int64(13)
# memory usage: 17.4 MB

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125690 entries, 0 to 125689
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            125690 non-null  int64
#  1   brand         125690 non-null  object
#  2   model         125690 non-null  object
#  3   model_year    125690 non-null  int64
#  4   milage        125690 non-null  int64
#  5   fuel_type     122307 non-null  object
#  6   engine        125690 non-null  object
#  7   transmission  125690 non-null  object
#  8   ext_col       125690 non-null  object
#  9   int_col       125690 non-null  object
#  10  accident      124058 non-null  object
#  11  clean_title   111451 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 11.5+ MB

# %%
from datetime import datetime

current_year = datetime.now().year
dt['model_year'] = current_year - dt['model_year'].astype(int)
dt.head()
# Out:
#        id brand                 model  model_year  milage fuel_type  \
# 0  188533  Land        Rover LR2 Base           9   98000  Gasoline
# 1  188534  Land     Rover Defender SE           4    9142    Hybrid
# 2  188535  Ford    Expedition Limited           2   28121  Gasoline
# 3  188536  Audi         A6 2.0T Sport           8   61258  Gasoline
# 4  188537  Audi  A6 2.0T Premium Plus           6   59000  Gasoline
#
#                                               engine        transmission  \
# 0       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 1  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 2                    3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 3                                     2.0 Liter TFSI           Automatic
# 4       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel                 A/T
#
#            ext_col int_col       accident clean_title
# 0            White   Beige  None reported         Yes
# 1           Silver   Black  None reported         Yes
# 2            White   Ebony  None reported         NaN
# 3  Silician Yellow   Black  None reported         NaN
# 4             Gray   Black  None reported         Yes

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
label_encoder = LabelEncoder()
dt['brand'] = label_encoder.fit_transform(dt['brand'])
dt['model'] = label_encoder.fit_transform(dt['model'])
dt['fuel_type'] = label_encoder.fit_transform(dt['fuel_type'])
dt['engine'] = label_encoder.fit_transform(dt['engine'])
dt['transmission'] = label_encoder.fit_transform(dt['transmission'])
dt['ext_col'] = label_encoder.fit_transform(dt['ext_col'])
dt['int_col'] = label_encoder.fit_transform(dt['int_col'])
dt['accident'] = label_encoder.fit_transform(dt['accident'])
dt['clean_title'] = label_encoder.fit_transform(dt['clean_title'])

# %%
id = sf.pop('id')
y_pred = model.predict(dt)

# Create a submission DataFrame
submission_df = pd.DataFrame({
    'id': id,
    'price': y_pred
})

# Save the submission DataFrame to a CSV file
submission_df.to_csv('submission_file.csv', index=False)
print("Submission file created: submission_file.csv")
# Out:
# Submission file created: submission_file.csv
